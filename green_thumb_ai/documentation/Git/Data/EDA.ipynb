# %%
# !pip install pandasql --quiet
# Out:
# ERROR: Could not find a version that satisfies the requirement graphlab (from versions: none)
# ERROR: No matching distribution found for graphlab

# %%
from google.colab import drive
import altair as alt
import pandas as pd
import numpy as np
import pandasql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-a8441cba3145> in <module>
#       4 import numpy as np
#       5 import pandasql
# ----> 6 import graphlab
#
# ModuleNotFoundError: No module named 'graphlab'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
drive.mount('/content/drive')
#drive.flush_and_unmount()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import Data
#DataFile = 'df.csv'
Path = '/content/drive/MyDrive/W210/Capstone/Data/'
DataFile1 = 'combined_NSRDB_data/combined_NSRDB_data.csv'
DataFile2 = 'companion_plants_veg.csv'
df1 = pd.read_csv(Path + DataFile1)
df2 = pd.read_csv(Path + DataFile2)

# %%
df1.head()
# Out:
#    Unnamed: 0  Month  month_DHI  month_GHI  month_clearsky_DHI  \
# 0           0      1       9290      22906                9222
# 1           1      2      15915      45631               15041
# 2           2      3      29867      61892               29480
# 3           3      4      51957     113583               40631
# 4           4      5      65547     118835               48083
#
#    month_clearsky_GHI  min_cloud_type  max_cloud_type  ave_cloud_type  \
# 0               22906               0               9               6
# 1               51875               0               9               5
# 2              116792               0               8               7
# 3              172611               0               8               5
# 4              227224               0               9               5
#
#    min_dew_point  ...  min_temp_F  max_temp_F  ave_temp_F  \
# 0          -21.0  ...           5          41   27.490323
# ...

# %%
df2.head()
# Out:
#    Common name        Scientific name  \
# 0      Alliums                 Allium
# 1    Asparagus  Asparagus officinalis
# 2  Beans, bush     Phaseolus vulgaris
# 3  Beans, pole     Phaseolus vulgaris
# 4  Beans, fava             Vicia faba
#
#                                                Helps  \
# 0  Fruit trees, nightshades (tomatoes, capsicum p...
# 1                                  Tomatoes, parsley
# 2                   Cucumber, soybeans, strawberries
# 3                                                NaN
# 4                                                NaN
#
#                                            Helped by  \
# 0  Carrots, tomatoes, carrots and African spider ...
# 1  Aster family flowers, dill, coriander, tomatoe...
# 2                       Celery, strawberries, grains
# 3                                     Radishes, Corn
# 4                               Strawberries, Celery
#
#                                           Attracts  \
# ...
